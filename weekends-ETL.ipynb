# %%
import pandas as pd 
import datetime as DT
import numpy as np
import os

# %%
weekends = pd.read_csv("weekends.csv")

# %%
weekends.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0      realSum        room_type  room_shared  \
# 0             0           0   319.640053     Private room        False
# 1             1           1   347.995219     Private room        False
# 2             2           2   482.975183     Private room        False
# 3             3           3   485.552926     Private room        False
# 4             4           4  2771.541724  Entire home/apt        False
#
#    room_private  person_capacity  host_is_superhost  multi  biz  ...  \
# 0          True              2.0              False      0    1  ...
# 1          True              2.0              False      0    1  ...
# 2          True              4.0              False      0    1  ...
# 3          True              2.0               True      0    0  ...
# 4         False              4.0               True      0    0  ...
#
#    bedrooms      dist  metro_dist  attr_index  attr_index_norm  rest_index  \
# ...

# %%
weekends.dropna()
# Out:
#        Unnamed: 0.1  Unnamed: 0      realSum        room_type  room_shared  \
# 0                 0           0   319.640053     Private room        False
# 1                 1           1   347.995219     Private room        False
# 2                 2           2   482.975183     Private room        False
# 3                 3           3   485.552926     Private room        False
# 4                 4           4  2771.541724  Entire home/apt        False
# ...             ...         ...          ...              ...          ...
# 26202          1794        1794   715.938574  Entire home/apt        False
# 26203          1795        1795   304.793960  Entire home/apt        False
# 26204          1796        1796   637.168969  Entire home/apt        False
# 26205          1797        1797   301.054157     Private room        False
# 26206          1798        1798   133.230489     Private room        False
#
# ...

# %%
weekends.head()
# Out:
#    Unnamed: 0      realSum        room_type  room_shared  room_private  \
# 0           0   319.640053     Private room        False          True
# 1           1   347.995219     Private room        False          True
# 2           2   482.975183     Private room        False          True
# 3           3   485.552926     Private room        False          True
# 4           4  2771.541724  Entire home/apt        False         False
#
#    person_capacity  host_is_superhost  multi  biz  cleanliness_rating  ...  \
# 0              2.0              False      0    1                 9.0  ...
# 1              2.0              False      0    1                 9.0  ...
# 2              4.0              False      0    1                 9.0  ...
# 3              2.0               True      0    0                10.0  ...
# 4              4.0               True      0    0                10.0  ...
#
#    bedrooms      dist  metro_dist  attr_index  attr_index_norm  rest_index  \
# ...

# %%
weekends = weekends.drop('Unnamed: 0', axis=1)

# %%
weekends.head()
# Out:
#        realSum        room_type  room_shared  room_private  person_capacity  \
# 0   319.640053     Private room        False          True              2.0
# 1   347.995219     Private room        False          True              2.0
# 2   482.975183     Private room        False          True              4.0
# 3   485.552926     Private room        False          True              2.0
# 4  2771.541724  Entire home/apt        False         False              4.0
#
#    host_is_superhost  multi  biz  cleanliness_rating  \
# 0              False      0    1                 9.0
# 1              False      0    1                 9.0
# 2              False      0    1                 9.0
# 3               True      0    0                10.0
# 4               True      0    0                10.0
#
#    guest_satisfaction_overall  bedrooms      dist  metro_dist  attr_index  \
# 0                        88.0         1  4.763360    0.852117  110.906123
# ...

# %%
weekends.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26207 entries, 0 to 26206
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   realSum                     26207 non-null  float64
#  1   room_type                   26207 non-null  object
#  2   room_shared                 26207 non-null  bool
#  3   room_private                26207 non-null  bool
#  4   person_capacity             26207 non-null  float64
#  5   host_is_superhost           26207 non-null  bool
#  6   multi                       26207 non-null  int64
#  7   biz                         26207 non-null  int64
#  8   cleanliness_rating          26207 non-null  float64
#  9   guest_satisfaction_overall  26207 non-null  float64
#  10  bedrooms                    26207 non-null  int64
#  11  dist                        26207 non-null  float64
#  12  metro_dist                  26207 non-null  float64
# ...

# %%
# Number of room_shared == True
weekends['room_shared'].values.sum()
# Out:
# 186

# %%
# Number of room_private == True
weekends['room_private'].values.sum()
# Out:
# 9367

# %%
print(len(weekends[weekends['room_type'] == 'Private room']))
# Out:
# 9367

# %%
weekends = weekends.drop('room_shared', axis=1)
weekends = weekends.drop('room_private', axis=1)

# %%
weekends.head()
# Out:
#        realSum        room_type  person_capacity  host_is_superhost  multi  \
# 0   319.640053     Private room              2.0              False      0
# 1   347.995219     Private room              2.0              False      0
# 2   482.975183     Private room              4.0              False      0
# 3   485.552926     Private room              2.0               True      0
# 4  2771.541724  Entire home/apt              4.0               True      0
#
#    biz  cleanliness_rating  guest_satisfaction_overall  bedrooms      dist  \
# 0    1                 9.0                        88.0         1  4.763360
# 1    1                 9.0                        87.0         1  5.748310
# 2    1                 9.0                        90.0         2  0.384872
# 3    0                10.0                        98.0         1  0.544723
# 4    0                10.0                       100.0         3  1.686798
#
# ...

# %%
print(len(weekends[weekends['multi'] == 1]))
# Out:
# 7580

# %%
weekends.to_csv('weekends.csv')

# %%
weekends = pd.read_csv("./Resources/weekends.csv")
weekdays = pd.read_csv("./Resources/weekdays.csv")

# %%
weekends['type'] = 'weekends'
weekdays['type'] = 'weekdays'

# %%
weekends.head(5)
# Out:
#        realSum        room_type  person_capacity  host_is_superhost  multi  \
# 0   319.640053     Private room                2              False      0
# 1   347.995220     Private room                2              False      0
# 2   482.975183     Private room                4              False      0
# 3   485.552926     Private room                2               True      0
# 4  2771.541724  Entire home/apt                4               True      0
#
#    biz  cleanliness_rating  guest_satisfaction_overall  bedrooms      dist  \
# 0    1                   9                          88         1  4.763360
# 1    1                   9                          87         1  5.748310
# 2    1                   9                          90         2  0.384872
# 3    0                  10                          98         1  0.544723
# 4    0                  10                         100         3  1.686798
#
# ...

# %%
weekends.to_csv('./Resources/weekends.csv')
weekdays.to_csv('./Resources/weekdays.csv')
